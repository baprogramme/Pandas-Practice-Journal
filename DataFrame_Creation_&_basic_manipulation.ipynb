# %% [markdown]
# Create a DataFrame from a dictionary of lists.

# %%
import pandas as pd
data = {'X' : [1,2,3,4], 'Y' : [5,6,7,8]}
df = pd.DataFrame(data)
print(df)
# Out:
#    X  Y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# Select the first 3 rows of a DataFrame.

# %%
df.head(3)
# Out:
#    X  Y
# 0  1  5
# 1  2  6
# 2  3  7

# %% [markdown]
# Select the 'X' column from a DataFrame.

# %%
df['X']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: X, dtype: int64

# %% [markdown]
# Filter rows based on a column condition.

# %%
df[df['X']<3]
# Out:
#    X  Y
# 0  1  5
# 1  2  6

# %% [markdown]
# Add a new column to an existing DataFrame.

# %%
df['Z'] = 3*df['X']
print(df)
# Out:
#    X  Y   Z
# 0  1  5   3
# 1  2  6   6
# 2  3  7   9
# 3  4  8  12

# %% [markdown]
# Remove a column from a DataFrame.

# %%
df.drop(columns = ['Z','Y'], axis=1, inplace = True)

# %%
df
# Out:
#    X
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# Sort a DataFrame by a column.

# %%
df.sort_values(by='X',inplace = True)
df
# Out:
#    X  Y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# Group a DataFrame by a column and calculate the mean of each group.

# %%
grouped_df = df.groupby('X').mean()
grouped_df
# Out:
#      Y
# X
# 1  5.0
# 2  6.0
# 3  7.0
# 4  8.0

# %% [markdown]
# Replace missing values in a DataFrame.

# %%
data = {'A' : [1,2,None,3,4], 'B' : [6,None,7,8,None]}
df = pd.DataFrame(data)
df.fillna(0, inplace = True)
print(df)
# Out:
#      A    B
# 0  1.0  6.0
# 1  2.0  0.0
# 2  0.0  7.0
# 3  3.0  8.0
# 4  4.0  0.0

# %% [markdown]
# Convert a column to datetime.

# %%
data = {'Date' : ['2023-01-01','2023-01-02','2023-01-03','2023-01-04']}
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
print(df)
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
